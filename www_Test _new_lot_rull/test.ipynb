# %%
# Out:
# Running cells with 'c:\Users\twn5287\AppData\Local\Microsoft\WindowsApps\python3.11.exe' requires ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/twn5287/AppData/Local/Microsoft/WindowsApps/python3.11.exe -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# # Ship's Instruction Manual
